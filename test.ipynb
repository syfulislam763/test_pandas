# %%
import pandas as pd
df = pd.read_csv("AB_NYC_2019.csv")
df.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# ...

# %%
df.price.describe()
# Out:
# count    7390.000000
# mean      167.145873
# std       278.992369
# min        10.000000
# 25%        80.000000
# 50%       120.000000
# 75%       185.000000
# max      9999.000000
# Name: price, dtype: float64

# %%
minthresold, maxthresold = df.price.quantile([0.01, 0.999])
minthresold, maxthresold
# Out:
# (35.0, 4305.500000000393)

# %%
df[df.price < minthresold]
# Out:
#            id                                             name   host_id  \
# 469    165824                   Lady only Curtain-divided room    733894
# 747    270315                              Bed-stuy Royal Room   1398639
# 776    278145               Large Room in a Huge NY apartment.   1452026
# 845    296844                  HISTORIC WILLIAMSBURG, BKLYN #1    839679
# 957    375249                  Enjoy Staten Island Hospitality   1887999
# 1965   858695              Very Large Private Room on quiet st   4494343
# 2062   924658              Bright, airy room share in Brooklyn   4973668
# 2675  1428154              Central, Peaceful Semi-Private Room   5912572
# 2860  1620248    Large furnished 2 bedrooms- - 30 days Minimum   2196224
# 2887  1652236                            Amazing Spacious Room   3562322
# 3020  1767037               Small Cozy Room Wifi & AC near JFK   9284163
# 3165  1886978                          Sunny & Budget Friendly   9522524
# ...

# %%
df2 = df[(df.price>minthresold)&(df.price<maxthresold)]
df2.shape
# Out:
# (7304, 16)

# %%
df2.sample(5)
# Out:
#            id                                    name   host_id  \
# 4869  3473305                   One bedroom apartment  16718001
# 4283  2838354     Large 1-bedroom, 2 blocks from park   8867917
# 2438  1217046          Sunny Williamsburg Apt w/ Deck    645887
# 5449  3944499  Cozy Bedroom in Crown Heights Brooklyn   6771709
# 3532  2107939     Private Single Room Steps to Subway   1318137
#
#            host_name neighbourhood_group       neighbourhood  latitude  \
# 4869        Nicholas            Brooklyn  Bedford-Stuyvesant  40.68887
# 4283          Steven            Brooklyn    Prospect Heights  40.67446
# 2438  Dave & Theresa            Brooklyn        Williamsburg  40.71317
# 5449          Lauren            Brooklyn       Crown Heights  40.67081
# 3532         Adriano            Brooklyn  Bedford-Stuyvesant  40.69193
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# ...

# %%
df2.price.describe()
# Out:
# count    7304.000000
# mean      161.901698
# std       185.028394
# min        36.000000
# 25%        80.000000
# 50%       121.500000
# 75%       185.000000
# max      4000.000000
# Name: price, dtype: float64
